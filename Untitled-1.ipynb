# %%
import numpy as np

# %%
number_paramters=10

# %%
DEFAULT_ALPHAS= [x for x in range(2, 200)]
K=np.random.randint(1,20,number_paramters)
THETA=np.linspace(0.001, 10, number_paramters)

# %%
valid_paramters=[(k, theta, alpha) for alpha in DEFAULT_ALPHAS for k, theta in zip(K,THETA) if alpha < (1/theta) and k > ((-1) * (np.log(2*alpha-1)/alpha) / (np.log(1-(alpha-1) * theta)))]

# %%
len(valid_paramters)
# Out:
# 180

# %%
valid_paramters=[(k, theta, alpha) for alpha in DEFAULT_ALPHAS for theta in THETA for k in K if alpha < (1/theta) and k > ((-1) * (np.log(2*alpha-1)/alpha) / (np.log(1-(alpha-1) * theta)))]

# %%
import numpy as np

# Example values, replace with your actual values
number_paramters = 10
DEFAULT_ALPHAS = [x for x in range(2, 200)]
K = np.random.randint(1, 20, number_paramters)
THETA = np.linspace(0.001, 10, number_paramters)

# Creating the list of pairs
pairs = []
for alpha in DEFAULT_ALPHAS:
    for k, theta in zip(K, THETA):
        if alpha < (1/theta) and k > ((-1) * (np.log(2*alpha-1)/alpha) / (np.log(1-(alpha-1) * theta))):
            pairs.append((alpha, k, theta))

len(pairs)
# Out:
# 180

# %%
import numpy as np

# Example values, replace with your actual values
number_paramters = 10
DEFAULT_ALPHAS = [x for x in range(2, 200)]
K = np.random.randint(1, 20, number_paramters)
THETA = np.linspace(0.001, 10, number_paramters)

# Creating the list of pairs
pairs = []
for alpha in DEFAULT_ALPHAS:
    for k in K:
        for theta in THETA:
            if alpha < (1/theta) and k > ((-1) * (np.log(2*alpha-1)/alpha) / (np.log(1-(alpha-1) * theta))):
                pairs.append((alpha, k, theta))

len(pairs)
# Out:
# 1694

# %%
alpha_thetas=[(theta, alpha)for alpha in DEFAULT_ALPHAS for theta in THETA if alpha < (1/theta)]

# %%
len(alpha_thetas)
# Out:
# 198

# %%
pairs=[]
for alpha_theta in alpha_thetas :
    alpha=alpha_theta[1]
    theta = alpha_theta[0]
    for k in K: 
        print((np.log(2*alpha-1)/alpha))
        print((np.log(1-(alpha-1) * theta)))

        if k > ((-1) * (np.log(2*alpha-1)/alpha) / (np.log(1-(alpha-1) * theta))):
            pairs.append((alpha_theta[0], alpha_theta[1], k))


len(pairs)
# Out:
# 0.5493061443340549
# -0.0010005003335835344
# 0.5493061443340549
# -0.0010005003335835344
# 0.5493061443340549
# -0.0010005003335835344
# 0.5493061443340549
# -0.0010005003335835344
# 0.5493061443340549
# -0.0010005003335835344
# 0.5493061443340549
# -0.0010005003335835344
# 0.5493061443340549
# -0.0010005003335835344
# 0.5493061443340549
# -0.0010005003335835344
# 0.5493061443340549
# -0.0010005003335835344
# 0.5493061443340549
# -0.0010005003335835344
# 0.5364793041447001
# -0.0020020026706730793
# 0.5364793041447001
# -0.0020020026706730793
# 0.5364793041447001
# -0.0020020026706730793
# 0.5364793041447001
# -0.0020020026706730793
# 0.5364793041447001
# -0.0020020026706730793
# 0.5364793041447001
# -0.0020020026706730793
# 0.5364793041447001
# -0.0020020026706730793
# 0.5364793041447001
# -0.0020020026706730793
# 0.5364793041447001
# -0.0020020026706730793
# 0.5364793041447001
# -0.0020020026706730793
# 0.4864775372638283
# -0.0030045090202987243
# 0.4864775372638283
# ...
